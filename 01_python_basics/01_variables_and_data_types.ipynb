# %%
numbers = [10, 20, 30, 40]

# %%
a = 5
b = 10
print(a + b)
# Out:
# 15

# %%
interest_rate = 0.0575
loan_amount = 350000
credit_score = 742
default_probability = 0.018

# %%
daily_returns = [0.01, -0.004, 0.006, 0.012]

# %%
customer = {
    "income": 95000,
    "loan": 280000,
    "fico": 730
}

# %% [markdown]
# # Python Fundamentals - Variables and Data Types
#
# ## Objectives
#
# By the end of this lesson, I will be able to:
#
# - Create variables
# - Understand Python data types
# - Perform arithmetic operations
# - Apply variables to quantitative finance examples
#
# Author: Mukhtarbek Abdurazakov

# %%
age = 35

print(age)
# Out:
# 35

# %%
age = 35
salary = 125000.50
name = "Mukhtarbek"
is_employed = True

print(type(age))
print(type(salary))
print(type(name))
print(type(is_employed))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
borrower_name = "John Smith"

loan_amount = 350000

interest_rate = 0.0625

credit_score = 742

default_probability = 0.018

print(borrower_name)
print(loan_amount)
print(interest_rate)
print(credit_score)
print(default_probability)
# Out:
# John Smith
# 350000
# 0.0625
# 742
# 0.018

# %%
loan_amount = 350000
down_payment = 70000
remaining_balance = loan_amount - down_payment
print(remaining_balance)
# Out:
# 280000

# %%
income = 120000
tax_rate = 0.22
tax = income * tax_rate
after_tax_income = income - tax
print(after_tax_income)
# Out:
# 93600.0

# %%
loan_amount 
interest_rate
# Out:
# 0.0625

# %%
customer_name = "John Smith"
annual_income = 95000
monthly_expenses = 2500
savings = 20000
fico_score = 720

print(customer_name)
print(annual_income)
print(monthly_expenses)
print(savings)
print(fico_score)
# Out:
# John Smith
# 95000
# 2500
# 20000
# 720

# %%
income = 95000
expenses = 52000

savings = income - expenses
print(savings)
# Out:
# 43000

# %% [markdown]
# ## Summary
#
# Today I learned:
#
# - Variables
# - Integers
# - Floats
# - Strings
# - Booleans
# - Arithmetic
# - Naming conventions
#
# These concepts are the foundation of every Python program.
